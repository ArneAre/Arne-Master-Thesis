# %%
import pandas as pd
from gensim.models.wrappers import DtmModel
from gensim.corpora import Dictionary
import pickle  # Import pickle for serialization

# Load my preprocessed dataset
print("Loading data...")
df = pd.read_csv('/mnt/c/Users/arnea/OneDrive/Desktop/Thesis/Work/Python/df_preprocessedv7.csv')
df['Date'] = pd.to_datetime(df['Date'])

# Preparing documents
print("Preparing documents...")
documents = [doc.split() for doc in df['Processed_Article'].dropna()]

# Prepare timestamps for monthly time slices
print("Preparing time slices...")
df['YearMonth'] = df['Date'].dt.to_period('M')
timestamps = df['YearMonth'].dt.strftime('%Y-%m').unique().tolist()
time_slices = [df['YearMonth'].value_counts()[period] for period in sorted(df['YearMonth'].unique())]

# Create a dictionary representation of the documents
print("Creating dictionary...")
dictionary = Dictionary(documents)

# Create a corpus from the dictionary and documents
print("Creating corpus...")
corpus = [dictionary.doc2bow(doc) for doc in documents]

# Define the path to the DTM binary
dtm_path = '/home/arne/dtm/dtm/main'

# Initialize and train the DTM model
print("Training DTM model...")
num_topics = 17
model = DtmModel(dtm_path, corpus=corpus, time_slices=time_slices, num_topics=num_topics, id2word=dictionary)

# Save the model to disk
print("Saving model...")
with open('dtm_model5.pkl', 'wb') as file:
    pickle.dump(model, file)

# Load the model from disk
print("Loading model from disk...")
with open('dtm_model5.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

# Displaying topics
print("Displaying topics...")
topics = loaded_model.print_topics()
for topic in topics:
    print(topic)

# Loop over each time slice to gather topic information
print("Gathering topic information over time...")
all_topics = []
for time_slice in range(len(time_slices)):
    print(f"Processing time slice {time_slice + 1}/{len(time_slices)}...")
    for topic_num in range(num_topics):
        top_words = loaded_model.show_topic(topicid=topic_num, time=time_slice, topn=20)
        topic_info = {
            "TimeSlice": time_slice,
            "TopicNum": topic_num,
            "Words": [word for word, _ in top_words],
            "Weights": [weight for _, weight in top_words]
        }
        all_topics.append(topic_info)

# Convert the list of dictionaries into a DataFrame
topics_df = pd.DataFrame(all_topics)

# Save the DataFrame to a CSV for further analysis
print("Saving topics dataframe...")
topics_df.to_csv("dtm_topics_over_timev5.csv", index=False)
print("Process completed successfully.")
# Out:
# Loading data...
# Preparing documents...
# Preparing time slices...
# Creating dictionary...
# /tmp/ipykernel_70/1738868933.py:17: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df['YearMonth'] = df['Date'].dt.to_period('M')
# Creating corpus...
# Training DTM model...
# Saving model...
# Loading model from disk...
# Displaying topics...
# 0.042*cil + 0.039*govern + 0.033*stake + 0.030*share + 0.030*compani + 0.021*sale + 0.020*union + 0.019*percent + 0.014*disinvest + 0.013*sell
# 0.058*minist + 0.023*govern + 0.017*jaiswal + 0.017*bjp + 0.017*demand + 0.015*parti + 0.014*prime + 0.014*issu + 0.012*congress + 0.010*leader
# 0.039*cbi + 0.035*report + 0.031*court + 0.017*investig + 0.015*govern + 0.015*alloc + 0.014*minist + 0.012*law + 0.012*probe + 0.011*block
# 0.079*block + 0.037*alloc + 0.029*govern + 0.027*mine + 0.026*ministri + 0.022*compani + 0.019*state + 0.013*allot + 0.012*power + 0.011*privat
# 0.036*cbi + 0.029*block + 0.026*compani + 0.023*jindal + 0.022*alloc + 0.022*steel + 0.019*alleg + 0.018*case + 0.014*agenc + 0.013*gupta
# 0.051*mine + 0.028*project + 0.018*cil + 0.016*plan + 0.015*land + 0.014*compani + 0.013*coalfield + 0.013*product + 0.012*ministri + 0.011*clearanc
# 0.042*govern + 0.039*cil + 0.033*stake + 0.030*share + 0.029*compani + 0.023*union + 0.022*sale + 0.016*disinvest + 0.015*percent + 0.013*sell
# 0.056*minist + 0.023*govern + 0.020*bjp + 0.016*prime + 0.015*demand + 0.015*parti + 0.013*issu + 0.012*jaiswal + 0.012*congress + 0.012*leader
# 0.043*cbi + 0.027*report + 0.025*court + 0.017*investig + 0.016*alloc + 0.016*file + 0.015*minist + 0.015*govern + 0.013*block + 0.012*probe
# 0.014*ga + 0.011*countri + 0.011*sector + 0.009*need + 0.009*product + 0.009*privat + 0.009*polici + 0.008*plan + 0.008*govern + 0.008*oil
# 0.012*worker + 0.009*strike + 0.009*union + 0.008*bccl + 0.008*peopl + 0.007*work + 0.007*offic + 0.007*famili + 0.006*mine + 0.006*gener
# 0.052*port + 0.040*railway + 0.032*transport + 0.028*handl + 0.016*termin + 0.013*import + 0.011*cargo + 0.011*berth + 0.011*oper + 0.010*ore
# 0.058*power + 0.030*price + 0.026*import + 0.017*suppli + 0.015*cost + 0.013*fuel + 0.012*plant + 0.012*sector + 0.011*produc + 0.011*cil
# 0.078*block + 0.036*alloc + 0.029*govern + 0.027*ministri + 0.026*mine + 0.022*compani + 0.019*state + 0.013*allot + 0.012*power + 0.011*privat
# 0.036*cbi + 0.028*block + 0.026*compani + 0.024*jindal + 0.022*alloc + 0.021*steel + 0.019*alleg + 0.018*case + 0.014*agenc + 0.014*gupta
# 0.051*mine + 0.026*project + 0.017*cil + 0.016*plan + 0.015*land + 0.014*compani + 0.014*coalfield + 0.013*product + 0.012*ministri + 0.011*limit
# Gathering topic information over time...
# Processing time slice 1/130...
# Processing time slice 2/130...
# Processing time slice 3/130...
# Processing time slice 4/130...
# Processing time slice 5/130...
# Processing time slice 6/130...
# Processing time slice 7/130...
# Processing time slice 8/130...
# Processing time slice 9/130...
# Processing time slice 10/130...
# Processing time slice 11/130...
# Processing time slice 12/130...
# Processing time slice 13/130...
# Processing time slice 14/130...
# Processing time slice 15/130...
# Processing time slice 16/130...
# Processing time slice 17/130...
# Processing time slice 18/130...
# Processing time slice 19/130...
# Processing time slice 20/130...
# Processing time slice 21/130...
# Processing time slice 22/130...
# Processing time slice 23/130...
# Processing time slice 24/130...
